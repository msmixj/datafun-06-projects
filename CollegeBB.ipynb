# %% [markdown]
# Task 3 - Exploratory Data Project

# %% [markdown]
# Susie Smith

# %% [markdown]
# February 21, 2023

# %% [markdown]
# CollegeBB.ipynb

# %%
import pandas as pd

# %%
cbb = pd.read_csv('cbb.csv') #Loading College BB dataset into a DataFrame.

# %%
pd.set_option('display.precision',2) #Rounding stats to nearesth hundredth.

# %%
pd.set_option('display.max_columns', None) #Setting the dataset up so that we can see all of the columns.

# %%
cbb #Loading and displaying dataset.
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0         North Carolina   ACC  40  33  123.3   94.9     0.95   52.6   48.1
# 1              Wisconsin   B10  40  36  129.1   93.6     0.98   54.8   47.7
# 2               Michigan   B10  40  33  114.4   90.4     0.94   53.9   47.7
# 3             Texas Tech   B12  38  31  115.2   85.2     0.97   53.5   43.0
# 4                Gonzaga   WCC  39  37  117.8   86.3     0.97   56.6   41.1
# ...                  ...   ...  ..  ..    ...    ...      ...    ...    ...
# 2450        Michigan St.   B10  35  26  111.4   87.8     0.94   50.6   44.5
# 2451             Arizona   P12  35  27  114.4   92.2     0.92   52.5   46.6
# 2452              Oregon   P12  37  28  104.8   88.6     0.87   49.3   46.4
# 2453            La Salle   A10  34  24  112.0   96.2     0.85   51.9   49.3
# 2454  Florida Gulf Coast  ASun  35  24  103.4   96.3     0.70   51.6   46.9
#
# ...

# %% [markdown]
# Let's look at the data and figure out what trends we can find.

# %% [markdown]
# In Order to Understand the Data Better, Let's Provide the Keys to Each Column Abbreviation:

# %% [markdown]
# G: Number of games played
#
# W: Number of games won
#
# ADJOE: Adjusted Offensive Efficiency (An estimate of the offensive efficiency (points scored per 100 possessions) a team would have against the average Division I defense)
#
# ADJDE: Adjusted Defensive Efficiency (An estimate of the defensive efficiency (points allowed per 100 possessions) a team would have against the average Division I offense)
#
# BARTHAG: Power Rating (Chance of beating an average Division I team)
#
# EFG_O: Effective Field Goal Percentage Shot
#
# EFG_D: Effective Field Goal Percentage Allowed
#
# TOR: Turnover Percentage Allowed (Turnover Rate)
#
# TORD: Turnover Percentage Committed (Steal Rate)
#
# ORB: Offensive Rebound Rate
#
# DRB: Offensive Rebound Rate Allowed
#
# FTR : Free Throw Rate (How often the given team shoots Free Throws)
#
# FTRD: Free Throw Rate Allowed
#
# 2P_O: Two-Point Shooting Percentage
#
# 2P_D: Two-Point Shooting Percentage Allowed
#
# 3P_O: Three-Point Shooting Percentage
#
# 3P_D: Three-Point Shooting Percentage Allowed
#
# ADJ_T: Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes) a team would have against the team that wants to play at an average Division I tempo)
#
# WAB: Wins Above Bubble (The bubble refers to the cut off between making the NCAA March Madness Tournament and not making it)
#
# POSTSEASON: Round where the given team was eliminated or where their season ended (R68 = First Four, R64 = Round of 64, R32 = Round of 32, S16 = Sweet Sixteen, E8 = Elite Eight, F4 = Final Four, 2ND = Runner-up, Champion = Winner of the NCAA March Madness Tournament for that given year)
#
# SEED: Seed in the NCAA March Madness Tournament

# %%
cbb["TEAM"].nunique() #How many unique teams are included in our dataset?
# Out:
# 355

# %% [markdown]
# That's a pretty big number! Maybe we could look at conference data:

# %%
cbb['CONF'].nunique() #How many unique conferences are included in our dataset?
# Out:
# 35

# %%
cbb['CONF'].unique() #List the names of each conference.
# Out:
# array(['ACC', 'B10', 'B12', 'WCC', 'SEC', 'BE', 'Amer', 'P12', 'A10',
#        'MVC', 'AE', 'ASun', 'BSky', 'BSth', 'BW', 'CAA', 'CUSA', 'Horz',
#        'Ind', 'Ivy', 'MAAC', 'MAC', 'MEAC', 'MWC', 'NEC', 'OVC', 'Pat',
#        'SB', 'SC', 'Slnd', 'Sum', 'SWAC', 'WAC', 'ind', 'GWC'],
#       dtype=object)

# %% [markdown]
# That's great information to know, but let's take a deeper look at the teams that made the postseason and compare their stats based on when they were eliminated from the tournament.

# %%
Postseason = cbb.loc[(cbb['POSTSEASON'] == 'Champions') | (cbb['POSTSEASON'] == '2ND') 
                     | (cbb['POSTSEASON'] == 'F4') | (cbb['POSTSEASON'] == 'E8') 
                     | (cbb['POSTSEASON'] == 'S16') | (cbb['POSTSEASON'] == 'R32')
                     | (cbb['POSTSEASON'] == 'R64') | (cbb['POSTSEASON'] == 'R68')]

# %%
Postseason #Loading dataframe of all teams that made it to the postseason tournament in years 2013-2021.
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0         North Carolina   ACC  40  33  123.3   94.9     0.95   52.6   48.1
# 1              Wisconsin   B10  40  36  129.1   93.6     0.98   54.8   47.7
# 2               Michigan   B10  40  33  114.4   90.4     0.94   53.9   47.7
# 3             Texas Tech   B12  38  31  115.2   85.2     0.97   53.5   43.0
# 4                Gonzaga   WCC  39  37  117.8   86.3     0.97   56.6   41.1
# ...                  ...   ...  ..  ..    ...    ...      ...    ...    ...
# 2450        Michigan St.   B10  35  26  111.4   87.8     0.94   50.6   44.5
# 2451             Arizona   P12  35  27  114.4   92.2     0.92   52.5   46.6
# 2452              Oregon   P12  37  28  104.8   88.6     0.87   49.3   46.4
# 2453            La Salle   A10  34  24  112.0   96.2     0.85   51.9   49.3
# 2454  Florida Gulf Coast  ASun  35  24  103.4   96.3     0.70   51.6   46.9
#
# ...

# %% [markdown]
# Let's compare the overall stats for each round of the tournament.

# %%
Postseason['POSTSEASON'].unique() #This proves we have the correct "rounds" of the tournament.
# Out:
# array(['2ND', 'Champions', 'E8', 'F4', 'R32', 'R64', 'R68', 'S16'],
#       dtype=object)

# %% [markdown]
# Let's create new DataFrames for each round and compare the average power rating to see if this is an indicator of making it far into the tournament.

# %%
Top68 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'R68']) #Top 68 teams
Top64 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'R64']) #Top 64 teams
Top32 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'R32']) #Top 32 teams
Top16 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'S16']) #Top 16 teams
Top8 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'E8']) #Top 8 teams
Top4 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'F4']) #Top 4 teams
Top2 = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == '2ND']) #Final 2 teams
Champs = pd.DataFrame(Postseason[Postseason['POSTSEASON'] == 'Champions']) #National Champions!

# %% [markdown]
# AVERAGE POWER RATINGS, ADJUSTED OFFENSIVE EFFICIENCY & ADJUSTED DEFENSIVE EFFICIENCY:

# %% [markdown]
# (BARTHAG = Power Rating; ADJOE = Adjusted Offensive Efficiency; ADJDE = Adjusted Defensive Efficiency)

# %%
Top68
# Out:
#                         TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  \
# 2371             Wake Forest   ACC  33  19  122.4  102.6     0.88   54.1
# 2372                   Tulsa  Amer  32  20  109.5   99.6     0.75   50.3
# 2373                  Temple  Amer  33  23  109.4   97.6     0.79   49.9
# 2374           North Florida  ASun  32  20  105.2  105.0     0.51   53.6
# 2375              Providence    BE  33  20  108.3   94.5     0.83   51.4
# 2376              St. John's    BE  34  21  107.4   99.5     0.71   51.9
# 2377               Manhattan  MAAC  33  19  100.2   99.4     0.52   49.4
# 2378  North Carolina Central  MEAC  31  25  101.4  101.3     0.50   51.3
# 2379  North Carolina Central  MEAC  32  19   95.0  110.3     0.15   50.4
# 2380  North Carolina Central  MEAC  31  18   98.0  108.3     0.24   49.9
# 2381               Boise St.   MWC  32  23  109.5   96.0     0.82   53.2
# 2382     Fairleigh Dickinson   NEC  32  17  103.0  115.6     0.21   51.2
# ...

# %% [markdown]
# Top 68 Teams

# %%
Top68[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.59
# ADJOE      107.33
# ADJDE      102.89
# dtype: float64

# %% [markdown]
# Top 64 Teams

# %%
Top64[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.72
# ADJOE      108.72
# ADJDE       98.54
# dtype: float64

# %% [markdown]
# Top32 Teams

# %%
Top32[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.86
# ADJOE      112.83
# ADJDE       95.06
# dtype: float64

# %% [markdown]
# Top 16 Teams

# %%
Top16[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.91
# ADJOE      115.51
# ADJDE       93.75
# dtype: float64

# %% [markdown]
# Top 8 Teams

# %%
Top8[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.93
# ADJOE      117.74
# ADJDE       92.81
# dtype: float64

# %% [markdown]
# Top 4 Teams

# %%
Top4[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.93
# ADJOE      116.37
# ADJDE       91.96
# dtype: float64

# %% [markdown]
# Top 2 Teams

# %%
Top2[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.95
# ADJOE      119.79
# ADJDE       91.47
# dtype: float64

# %% [markdown]
# Championship Teams

# %%
Champs[['BARTHAG', 'ADJOE', 'ADJDE']].mean()
# Out:
# BARTHAG      0.96
# ADJOE      121.30
# ADJDE       90.40
# dtype: float64

# %% [markdown]
# Histograms

# %%
# %matplotlib inline

histogram = Champs.hist()
